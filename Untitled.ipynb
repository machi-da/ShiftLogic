# %%
import numpy as np, pandas as pd
from pulp import *
from ortoolpy import addvars, addbinvars
from io import StringIO

# %%
a = pd.read_table(StringIO("""\
曜日\t月\t月\t月\t火\t火\t火\t水\t水\t水\t木\t木\t木\t金\t金\t金\t土\t土\t土\t日\t日\t日
時間帯\t朝\t昼\t夜\t朝\t昼\t夜\t朝\t昼\t夜\t朝\t昼\t夜\t朝\t昼\t夜\t朝\t昼\t夜\t朝\t昼\t夜
必要人数\t2\t3\t3\t2\t3\t3\t2\t3\t3\t1\t2\t2\t2\t3\t3\t2\t4\t4\t2\t4\t4
従業員0\t○\t\t\t○\t\t\t○\t\t\t○\t\t\t○\t\t\t○\t\t\t○\t\t
従業員1\t○\t○\t○\t\t\t\t○\t○\t○\t\t\t\t○\t○\t○\t\t\t\t\t\t
従業員2\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t○\t○\t○\t○\t○\t○
従業員3\t○\t○\t○\t○\t○\t○\t○\t○\t○\t○\t○\t○\t○\t○\t○\t○\t○\t○\t○\t○\t○
従業員4\t\t\t○\t\t\t○\t\t\t○\t\t\t○\t\t\t○\t\t\t○\t\t\t○
従業員5\t○\t○\t○\t○\t○\t○\t○\t○\t○\t○\t○\t○\t○\t○\t○\t\t\t\t\t\t
従業員6\t\t\t\t\t\t\t\t\t\t\t\t\t○\t○\t○\t○\t○\t○\t○\t○\t○
従業員7\t\t○\t\t\t○\t\t\t○\t\t\t○\t\t\t○\t\t\t○\t\t\t○\t
従業員8\t\t\t○\t\t\t○\t\t\t○\t\t\t○\t\t\t○\t\t\t○\t\t\t○
従業員9\t\t\t\t\t\t\t\t\t\t○\t○\t○\t○\t○\t○\t○\t○\t○\t○\t○\t○""")).T
a,a.columns = a.iloc[1:],a.iloc[0].tolist()
a.必要人数 = a.必要人数.astype(int)
a.iloc[:,2:] = ~a.iloc[:,2:].isnull()
# a.insert(0, '曜日', a.index.str[0])
# a.reset_index(drop=True, inplace=True)
# a = a.iloc[:,list(range(3,a.shape[1]))+[0,1,2]]
print(a[:3]) # 最初の3行表示
# Out:
#     時間帯  必要人数   従業員0  従業員1   従業員2  従業員3   従業員4  従業員5   従業員6   従業員7   従業員8  \
# 月     朝     2   True  True  False  True  False  True  False  False  False
# 月.1   昼     3  False  True  False  True  False  True  False   True  False
# 月.2   夜     3  False  True  False  True   True  True  False  False   True
#
#       従業員9
# 月    False
# 月.1  False
# 月.2  False

# %%
Nコマ,N従業員 = a.shape[0],a.shape[1]-3
L従業員 = list(range(N従業員))
L管理者 = [3,5,9] # 管理者は従業員3, 5, 9
C必要人数差 = 10
C希望不可 = 100
C最低コマ数 = 1
C管理者不足 = 100
C1日2コマ = 10
m = LpProblem() # 数理モデル
V割当 = np.array(addbinvars(Nコマ, N従業員))

# %%
a.iloc[0]
# Out:
# 時間帯         朝
# 必要人数        2
# 従業員0     True
# 従業員1     True
# 従業員2    False
# 従業員3     True
# 従業員4    False
# 従業員5     True
# 従業員6    False
# 従業員7    False
# 従業員8    False
# 従業員9    False
# Name: 月, dtype: object

# %%
a
# Out:
#     時間帯  必要人数   従業員0   従業員1   従業員2  従業員3   従業員4   従業員5   従業員6   従業員7   従業員8  \
# 月     朝     2   True   True  False  True  False   True  False  False  False
# 月.1   昼     3  False   True  False  True  False   True  False   True  False
# 月.2   夜     3  False   True  False  True   True   True  False  False   True
# 火     朝     2   True  False  False  True  False   True  False  False  False
# 火.1   昼     3  False  False  False  True  False   True  False   True  False
# 火.2   夜     3  False  False  False  True   True   True  False  False   True
# 水     朝     2   True   True  False  True  False   True  False  False  False
# 水.1   昼     3  False   True  False  True  False   True  False   True  False
# 水.2   夜     3  False   True  False  True   True   True  False  False   True
# 木     朝     1   True  False  False  True  False   True  False  False  False
# 木.1   昼     2  False  False  False  True  False   True  False   True  False
# 木.2   夜     2  False  False  False  True   True   True  False  False   True
# 金     朝     2   True   True  False  True  False   True   True  False  False
# 金.1   昼     3  False   True  False  True  False   True   True   True  False
# 金.2   夜     3  False   True  False  True   True   True   True  False   True
# 土     朝     2   True  False   True  True  False  False   True  False  False
# 土.1   昼     4  False  False   True  True  False  False   True   True  False
# 土.2   夜     4  False  False   True  True   True  False   True  False   True
# 日     朝     2   True  False   True  True  False  False   True  False  False
# 日.1   昼     4  False  False   True  True  False  False   True   True  False
# 日.2   夜     4  False  False   True  True   True  False   True  False   True
#
#       従業員9
# 月    False
# 月.1  False
# 月.2  False
# 火    False
# 火.1  False
# 火.2  False
# 水    False
# 水.1  False
# 水.2  False
# 木     True
# 木.1   True
# 木.2   True
# 金     True
# 金.1   True
# 金.2   True
# 土     True
# 土.1   True
# 土.2   True
# 日     True
# 日.1   True
# 日.2   True
